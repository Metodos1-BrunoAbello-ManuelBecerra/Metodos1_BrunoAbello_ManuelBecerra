# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = np.linspace(1, 80, 80)
días = 365
P = np.array([])
p = 1
for i in n:
    p *= (días - (i-1))/365
    P = np.append(P, p)

# %%
plt.plot(n, P)
plt.show()
